# %%
from pathlib import Path
import pandas as pd
from scipy.signal import find_peaks, peak_widths
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np
import colorsys
import os

# Dict of balmer lines and expected wavelengths
balmer_lines = {"Delta": 410, "Gamma": 434, "Beta": 486, "Fulcher": 590, "Alpha": 656}

def gauss(data, H, A, x0, sigma):
    return H + A * np.exp(-(data - x0) ** 2 / (2 * sigma ** 2))

def get_fit_errors(covariance_matrix):
    errors = []
    (num_parameters, _) = covariance_matrix.shape
    for i in range(num_parameters):
        errors.append(np.sqrt(np.diag(covariance_matrix))[i])
    return errors

def is_saturated(width_middle, width_top):
    if width_top / width_middle > 0.5:
        return True
    return False

class Trial:
    def __init__(self, file, saturation_line=None):
        self.file = file
        self.saturation_line = saturation_line
        self.integration_time, self.scans_to_average = self.parse_filename()
        self.data = self.read_data()
        self.peak_names, \
            self.peak_indices, \
            self.peak_wavelengths, \
            self.peak_intensities, \
            self.widths_middle, \
            self.widths_top, \
            self.saturated = self.find_peaks()
        
        self.H_params, \
            self.H_param_errors, \
            self.A_params, \
            self.A_param_errors, \
            self.x0_params, \
            self.x0_param_errors, \
            self.sigma_params, \
            self.sigma_param_errors = self.fit_all_balmer_lines()
        
    def parse_filename(self):
        parts = self.file.stem.split('_')
        assert len(parts) >= 8, "Found {} parts in the filename, should be at least 8".format(len(parts))
        assert parts[1][-2:] == "ms", "Integration time is in {}, should be in ms".format(parts[2][-2:])
        time = int(parts[1][:-2])
        return (time, parts[2])
        
    def read_data(self, skiprows=14):
        data = pd.read_csv(self.file.resolve(), skiprows=skiprows)
        data.columns = ['Wavelength', 'Intensity']
        return data

    def balmer_line_window(self, line, range_size):
        half_range_size = range_size / 2
        balmer_wavelength = balmer_lines[line]
        window_start = balmer_wavelength - half_range_size
        window_end = balmer_wavelength + half_range_size
        data_window = self.data.loc[(self.data['Wavelength'] >= window_start) & (self.data['Wavelength'] <= window_end)]
        return data_window

    def find_peaks(self):
        names = []
        indices = []
        wavelengths = []
        intensities = []
        widths_middle = []
        widths_top = []
        saturated = []
        for name, _ in balmer_lines.items():
            data_window = self.balmer_line_window(line=name, range_size=10)

            if data_window.empty:
                continue

            # Find the index with the max intensity, this is a peak
            peak_index = int(data_window['Intensity'].idxmax())
            peak_wavelength = data_window['Wavelength'][peak_index]
            peak_intensity = data_window['Intensity'][peak_index]
            assert peak_intensity == data_window['Intensity'].max(), "Indexmax should yield the max"
            
            width_middle = peak_widths(self.data['Intensity'], [peak_index], rel_height=0.5)[0][0]
            width_top = peak_widths(self.data['Intensity'], [peak_index], rel_height=0.05)[0][0]
            
            names.append(name)
            indices.append(peak_index)
            wavelengths.append(peak_wavelength)
            intensities.append(peak_intensity)
            widths_middle.append(width_middle)
            widths_top.append(width_top)
            saturated.append(is_saturated(width_middle, width_top))

        return (names, indices, wavelengths, intensities, widths_middle, widths_top, saturated)

    def graph_raw(self):
        data_graph = self.data.loc[(self.data['Wavelength'] >= 0) & (self.data['Wavelength'] <= 720)]
        plt.figure(figsize=(10, 6))
        plt.title("Detected Emission Peaks in Deuterium Spectrum, Integration Time: {}ms, Scans to Average: {}".format(self.integration_time, self.scans_to_average))
        plt.plot(data_graph['Wavelength'], data_graph['Intensity'], label="Intensity vs. Wavelength", color="k")

        if self.saturation_line:
            plt.axhline(y=self.saturation_line, color='red', linestyle=':', linewidth=1.5)

        plt.xlabel('Wavelength')
        plt.ylabel('Intensity')
        plt.yscale('log')
        for i, (name, x, y) in enumerate(zip(self.peak_names, self.peak_wavelengths, self.peak_intensities)):
            color = 'red' if self.saturated[i] else 'blue'
            plt.plot(x, y, "x", color=color)
            plt.text(x, y, name, fontsize=12, ha='right', va='bottom')
            print("{}: wavelength: {}, peak intensity: {}".format(name, x, y))
            print("middle width: {}, top width: {}, saturated: {}".format(self.widths_middle[i], self.widths_top[i], self.saturated[i]))
        plt.show()
        
    def balmer_fit_window(self, line, range_size=40):
        try:
            peak_index = self.peak_names.index(line)
            half_range_size = range_size / 2
            start = int(self.peak_indices[peak_index] - half_range_size)
            end = int(self.peak_indices[peak_index] + half_range_size)
            return (start, end)
        except ValueError:
            print("No peak found for {}".format(line))
            return None
        
    def fit_balmer_line(self, line):
        try:
            peak_index = self.peak_names.index(line)
            guess = [0, self.peak_intensities[peak_index], self.peak_wavelengths[peak_index], 1]
            start, end = self.balmer_fit_window(line)
            res = curve_fit(gauss, self.data['Wavelength'][start:end], self.data['Intensity'][start:end], guess)
            (H, A, x0, sigma) = (res[0][0], res[0][1], res[0][2], res[0][3])
            (H_error, A_error, x0_error, sigma_error) = get_fit_errors(res[1])
            return (H, H_error, A, A_error, x0, x0_error, sigma, sigma_error)
        except ValueError:
            print("No peak found for {}".format(line))
            return None
        
    def fit_all_balmer_lines(self):
        H_params = []
        H_param_errors = []
        A_params = []
        A_param_errors = []
        x0_params = []
        x0_param_errors = []
        sigma_params = []
        sigma_param_errors = []
        for line in self.peak_names:
            (H, H_error, A, A_error, x0, x0_error, sigma, sigma_error) = self.fit_balmer_line(line)
            H_params.append(H)
            H_param_errors.append(H_error)
            A_params.append(A)
            A_param_errors.append(A_error)
            x0_params.append(x0)
            x0_param_errors.append(x0_error)
            sigma_params.append(sigma)
            sigma_param_errors.append(sigma_error)
            
        return (H_params, H_param_errors, A_params, A_param_errors, x0_params, x0_param_errors, sigma_params, sigma_param_errors)
        
    def plot_all_fits(self):
        for i, line in enumerate(self.peak_names):
            plt.figure(figsize=(10, 6))
            plt.title("Gaussian Fit for {}, Integration Time: {}ms, Scans to Average: {}".format(line, self.integration_time, self.scans_to_average))
            start, end = self.balmer_fit_window(line)
            plt.plot(self.data['Wavelength'][start:end], self.data['Intensity'][start:end], label="Intensity vs. Wavelength", color="k")
            plt.plot(self.data['Wavelength'][start:end], gauss(self.data['Wavelength'][start:end], self.H_params[i], self.A_params[i], self.x0_params[i], self.sigma_params[i]), label="Intensity Fit vs. Wavelength", color="#d534eb")
            plt.xlabel('Wavelength')
            plt.ylabel('Intensity')
            plt.legend()
            plt.grid(True)
            print("{} gaussian parameters: H = {}, A = {}, x0 = {}, sigma = {}\nerrors: {}, {}, {}, {}".format(line, self.H_params[i], self.A_params[i], self.x0_params[i], self.sigma_params[i], self.H_param_errors[i], self.A_param_errors[i], self.x0_param_errors[i], self.sigma_param_errors[i]))
            plt.show()
            
    def plot_sigma_vs_wavelength(self):
        plt.figure(figsize=(10, 6))
        plt.title("Gaussian Sigmas vs Wavelength for Integration Time: {}ms, Scans to Average: {}".format(self.integration_time, self.scans_to_average))
        plt.xlabel('Wavelength')
        plt.ylabel('Sigma with Error')
        for i, (name, x, y) in enumerate(zip(self.peak_names, self.x0_params, self.sigma_params)):
            color = 'red' if self.saturated[i] else 'blue'
            plt.errorbar(self.x0_params[i], self.sigma_params[i], yerr=self.sigma_param_errors[i], fmt='o', label="Errors", color=color)
            plt.text(x, y, name, fontsize=12, ha='right', va='bottom')
        plt.show()
            
        
class Experiment:
    def __init__(self, folder, saturation_line=None):
        self.folder = folder
        
        os.makedirs("{}_plots".format(self.folder), exist_ok=True)
        
        self.trials = []
        self.saturation_line = saturation_line
        for file in folder.iterdir():
            if file.is_file():
                trial = Trial(file, saturation_line)
                self.trials.append(trial)
        self.trials = sorted(self.trials, key=lambda t: t.integration_time)
        self.colors = self.get_colors()
                
    def graph_all(self):
        for t in self.trials:
            t.graph_raw()
            t.plot_sigma_vs_wavelength()
            t.plot_all_fits()
            
    def get_colors(self):
        num_colors = len(self.trials)
        return [colorsys.hsv_to_rgb(i / num_colors, 0.8, 0.9) for i in range(num_colors)]
            
    def graph_balmer_line_combined(self, balmer_line, range_size, normalized=False, trials=None):
        plt.figure(figsize=(10, 6))
        title = "Balmer Line {}".format(balmer_line)
        plt.title(title)
        plot_trials = self.trials
        if trials:
            plot_trials = [t for t in plot_trials if t.integration_time in trials]
        for t, color in zip(plot_trials, self.colors):
            balmer_range = t.balmer_line_window(balmer_line, range_size)
            if normalized:
                # Multiply all data by a scale factor that converts the current peak to
                # the height of the tallest peak
                peak = balmer_range['Intensity'].max()
                plt.plot(balmer_range['Wavelength'], balmer_range['Intensity'] / t.integration_time, label="{}ms".format(t.integration_time), color=color)
            else:
                plt.plot(balmer_range['Wavelength'], balmer_range['Intensity'], label="{}ms".format(t.integration_time), color=color)
            plt.xlabel('Wavelength')
            plt.ylabel('Intensity')
            if not normalized:
                try:
                    peak_index = t.peak_names.index(balmer_line)
                    plt.plot(t.peak_wavelengths[peak_index], t.peak_intensities[peak_index], "x", color="r")
                except ValueError:
                    print("No peak found for {}".format(balmer_line))
        plt.legend()
        plt.savefig("{}_plots/{}_{}{}.pdf".format(self.folder, title.replace(" ", "_"), "_".join(map(str, trials)) if trials else "all_trials", "_normalized" if normalized else ""))
        plt.show()
        
    def graph_all_balmer_lines_combined(self, range_size, normalized=False, trials=None):
        # Go through all balmer lines, and call graph_balmer_line_combined with each
        for line in balmer_lines:
            self.graph_balmer_line_combined(line, range_size, normalized, trials=trials)
            
    def graph_sigma_vs_integration_time(self, balmer_line):
        plt.figure(figsize=(10, 6))
        plt.title("Sigma vs Integration Times for {}".format(balmer_line))

        # Vertical line where alpha integrates
        if balmer_line == "Alpha":
            plt.axvline(x=130, color='red', linestyle=':', linewidth=1.5)

        for t in self.trials:
            try:
                peak_index = t.peak_names.index(balmer_line)
                color = 'red' if t.saturated[peak_index] else 'blue'
                plt.errorbar(t.integration_time, t.sigma_params[peak_index], yerr=t.sigma_param_errors[peak_index], fmt='o', color=color)
            except ValueError:
                print("No peak found for {}".format(balmer_line))
        plt.show()
    
    def graph_all_sigmas_vs_integration_times(self):
        # Go through all balmer lines, and call graph_sigma_vs_integration_time with each
        for line in balmer_lines:
            self.graph_sigma_vs_integration_time(line)
        

# Example file name: deutdg_200ms_20_SR4014911__0__16-45-59-520.csv,
# where 200 is integration time, 20 is scans to average
folder = Path("/home/crystal/research/deuterium_analysis/filter_data")
experiment = Experiment(folder=folder, saturation_line=63500)
experiment.graph_all()
experiment.graph_all_balmer_lines_combined(25)
experiment.graph_all_balmer_lines_combined(25, normalized=True)
experiment.graph_all_balmer_lines_combined(25, normalized=True, trials=[4, 40, 80])
experiment.graph_all_sigmas_vs_integration_times()
# Out:
# Delta: wavelength: 409.186, peak intensity: 61.747569999999996
# middle width: 6.582284616584502, top width: 0.413942458161614, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 225.95628
# middle width: 7.392427635284207, top width: 1.2648329344104354, saturated: False
# Beta: wavelength: 484.973, peak intensity: 4122.115970000001
# middle width: 6.296851842300953, top width: 0.6895872054031997, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 311.55294
# middle width: 5.0319251062583135, top width: 0.9724472558471007, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 5125.4871299999995
# middle width: 4.917550686856885, top width: 1.2925197631707306, saturated: False
# Delta gaussian parameters: H = 28.001125714499377, A = 29.01559822615134, x0 = 408.9696361799255, sigma = 0.48612674759797136
# errors: 1.3596650162305026, 4.502521558583891, 0.0850892109999729, 0.09096806565025586
# Gamma gaussian parameters: H = 28.925512354330554, A = 160.3807517657951, x0 = 432.47905457405807, sigma = 0.7788432513961616
# errors: 5.040755117369565, 11.592376044636497, 0.061841332829545376, 0.07087148382153126
# Beta gaussian parameters: H = 78.08017767965889, A = 3337.3974284055225, x0 = 484.57061693942006, sigma = 0.7129431982286961
# errors: 89.56134421297347, 219.55240785809957, 0.05187199749083513, 0.05849680007807533
# Fulcher gaussian parameters: H = 48.43622980481695, A = 233.33645468729742, x0 = 588.3970271408884, sigma = 0.39423209180272917
# errors: 4.256103702441142, 15.667903391552882, 0.029988194536283465, 0.031682418308346706
# Alpha gaussian parameters: H = 61.673448485544306, A = 4863.200685771535, x0 = 655.2673396757073, sigma = 0.45060774362205486
# errors: 43.149297130610094, 143.1089359019098, 0.014950492726544971, 0.015989259700170847
# Delta: wavelength: 409.186, peak intensity: 96.4443
# middle width: 6.6831130607971545, top width: 2.7412525844482047, saturated: False
# Gamma: wavelength: 432.756, peak intensity: 394.96394
# middle width: 6.974331200760901, top width: 1.3175326082034076, saturated: False
# Beta: wavelength: 484.973, peak intensity: 8649.18517
# middle width: 6.31305502163616, top width: 0.873986841445344, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 692.31084
# middle width: 2.9094644818258075, top width: 0.7874433075705838, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 25677.11446
# middle width: 8.106974674289859, top width: 2.3572232990882185, saturated: False
# Delta gaussian parameters: H = 44.214251622958514, A = 54.453275007083555, x0 = 408.8878825406855, sigma = 0.47332354091952095
# errors: 2.248845977409967, 7.583207573008593, 0.07441739581107867, 0.07936692823428348
# Gamma gaussian parameters: H = 50.4988769802101, A = 295.7795480941131, x0 = 432.4995514190487, sigma = 0.7190733462250009
# errors: 7.98905995713383, 19.667480515507002, 0.05287545796134691, 0.05958118951277519
# Beta gaussian parameters: H = 157.12669641602855, A = 7291.607934824753, x0 = 484.5826409969221, sigma = 0.6798309397666967
# errors: 178.33258939536404, 454.54547148577973, 0.0470304072201736, 0.05257294314373629
# Fulcher gaussian parameters: H = 90.7852633391579, A = 525.1040964958088, x0 = 588.3864652975669, sigma = 0.3740056738671189
# errors: 9.459077666260297, 36.0217409699044, 0.029099057139019502, 0.030634288900976095
# Alpha gaussian parameters: H = -4.291124367855946, A = 26911.039697148823, x0 = 655.1888303284236, sigma = 0.646610455869259
# errors: 263.3245778735557, 668.7136702371458, 0.017815385352747338, 0.019938812498516534
# Delta: wavelength: 408.971, peak intensity: 120.18207
# middle width: 6.280386766707181, top width: 1.6007622640420323, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 525.25873
# middle width: 7.080306448915621, top width: 1.1917891713384847, saturated: False
# Beta: wavelength: 484.973, peak intensity: 11127.8031
# middle width: 6.965750124855504, top width: 0.8096679090832595, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 1116.93527
# middle width: 2.8478888794138584, top width: 0.7871215035520436, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 40539.91874
# middle width: 9.780631671831088, top width: 3.7869321220441634, saturated: False
# Delta gaussian parameters: H = 59.41088028900648, A = 62.861409305320294, x0 = 408.86431731667653, sigma = 0.454935452076694
# errors: 2.5575667617486655, 8.856607715460282, 0.07245428664102875, 0.07702030423967317
# Gamma gaussian parameters: H = 59.696369719506286, A = 379.5941949227471, x0 = 432.4633642715982, sigma = 0.7699605341696186
# errors: 11.372527342105816, 26.416595525144743, 0.05892551373402288, 0.06735395629529545
# Beta gaussian parameters: H = 135.8639397222896, A = 9308.668548548698, x0 = 484.5320912096067, sigma = 0.7278571181835155
# errors: 242.52844636505455, 584.3154476642604, 0.050449986815118315, 0.05712526496142693
# Fulcher gaussian parameters: H = 122.97887971252734, A = 877.7114216630748, x0 = 588.3700510747042, sigma = 0.354641660905712
# errors: 15.212271278416685, 59.91033163534142, 0.02749084801328212, 0.028843001403476832
# Alpha gaussian parameters: H = -328.7162889436609, A = 44846.52598705937, x0 = 655.1902681597506, sigma = 0.7524989758858297
# errors: 701.7979268121665, 1565.8396834100581, 0.02876932394631103, 0.033243807090975595
# Delta: wavelength: 408.971, peak intensity: 173.62364
# middle width: 5.887195193895593, top width: 1.3825711870562714, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 736.2758299999999
# middle width: 7.541252467828201, top width: 0.8790462914732871, saturated: False
# Beta: wavelength: 484.973, peak intensity: 15799.721290000001
# middle width: 7.264520162505619, top width: 0.7559214668298182, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 1447.3011
# middle width: 2.82688770744835, top width: 0.6854781265947167, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 31456.203289999998
# middle width: 12.409767704132719, top width: 1.9241011725473527, saturated: False
# Delta gaussian parameters: H = 83.01837440092781, A = 90.94547088540841, x0 = 408.9232154500679, sigma = 0.40528507824774196
# errors: 3.9674899217142636, 14.81883484006639, 0.07488545100189527, 0.07893603774037938
# Gamma gaussian parameters: H = 87.05380869818897, A = 525.891806234677, x0 = 432.4717669114727, sigma = 0.7542018777225628
# errors: 15.618216824384513, 36.932397118822145, 0.05835251643814744, 0.06639584892511863
# Beta gaussian parameters: H = 172.849750101827, A = 13287.213982800436, x0 = 484.5117510465651, sigma = 0.7511702803319594
# errors: 346.8266558326513, 813.4215297351914, 0.05064482081187589, 0.057728875930264344
# Fulcher gaussian parameters: H = 155.14239819840276, A = 1128.552401145395, x0 = 588.3748725358281, sigma = 0.3609833476024771
# errors: 20.058181715092392, 78.11852166394381, 0.02836557247265525, 0.029793678121023667
# Alpha gaussian parameters: H = -428.7742698583986, A = 31237.780599821825, x0 = 655.2895635730041, sigma = 0.902902692268977
# errors: 507.09847954667407, 946.5286334363747, 0.029228222093951792, 0.035830092104643524
# Delta: wavelength: 409.186, peak intensity: 218.03132000000002
# middle width: 5.90806737829331, top width: 0.6662143113836123, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 1017.6265900000001
# middle width: 5.993912698846657, top width: 0.9235895321112935, saturated: False
# Beta: wavelength: 484.973, peak intensity: 21077.33071
# middle width: 6.482900138629134, top width: 0.743938731510184, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 1524.8929999999998
# middle width: 2.8187133101048403, top width: 0.7274127452999437, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 29560.50743
# middle width: 6.405563964943212, top width: 1.3807231764965309, saturated: False
# Delta gaussian parameters: H = 102.5736684958234, A = 115.10760583653665, x0 = 408.89191571130203, sigma = 0.42789725167858655
# errors: 4.241135073290068, 15.292985670826383, 0.064374597356295, 0.06811350002653646
# Gamma gaussian parameters: H = 113.93828119056452, A = 743.7200274241885, x0 = 432.57444471041117, sigma = 0.6646900016988275
# errors: 19.966355415873984, 52.3819640886469, 0.052054073168537, 0.05784009473908586
# Beta gaussian parameters: H = 329.3598287179849, A = 17457.387694370045, x0 = 484.579135794158, sigma = 0.702842013266944
# errors: 449.33165468219426, 1114.6089763534815, 0.0496823775515622, 0.05587500375401582
# Fulcher gaussian parameters: H = 182.60126263817736, A = 1172.665689352733, x0 = 588.3738963386716, sigma = 0.3587732211780472
# errors: 21.345511003046948, 83.45661471308276, 0.028987989024032584, 0.0304358422110532
# Alpha gaussian parameters: H = 517.7001758134163, A = 25550.898418761688, x0 = 655.2657711551185, sigma = 0.6849698621004227
# errors: 397.7797481206886, 963.213275499208, 0.028509825767412827, 0.03225659442252683
# Delta: wavelength: 409.186, peak intensity: 311.02386
# middle width: 5.356490066240951, top width: 0.6093263327092018, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 1472.1770199999999
# middle width: 6.327048674591936, top width: 1.0562582698120764, saturated: False
# Beta: wavelength: 484.973, peak intensity: 28500.4006
# middle width: 7.1025829874486135, top width: 0.797683875006328, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 2524.78707
# middle width: 2.8471786992272428, top width: 0.722704440686357, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 40167.14701
# middle width: 7.118254117125389, top width: 1.4559488845166015, saturated: False
# Delta gaussian parameters: H = 142.585850692352, A = 164.90692975052562, x0 = 408.9239451588903, sigma = 0.3987751143946207
# errors: 6.680125410381387, 25.21476478763772, 0.06915069086632952, 0.0728126375388788
# Gamma gaussian parameters: H = 154.2797367670029, A = 1091.3081671982072, x0 = 432.52043021768895, sigma = 0.7061047322260677
# errors: 29.909621342938983, 74.7438918891507, 0.053553712120089386, 0.06013753864718967
# Beta gaussian parameters: H = 377.3318123911253, A = 23942.04513785205, x0 = 484.5388169452881, sigma = 0.7400323792256157
# errors: 611.8012515057508, 1453.4410444135722, 0.049536486767786804, 0.056285065199193116
# Fulcher gaussian parameters: H = 276.8369936973954, A = 1960.1909469055777, x0 = 588.3805380676133, sigma = 0.3688412169137144
# errors: 34.92209865506672, 134.16544405904307, 0.028644553273456153, 0.030128043273591053
# Alpha gaussian parameters: H = 2912.442710771786, A = 32804.565809161686, x0 = 655.2568406444746, sigma = 0.6968977946315346
# errors: 836.3191709235758, 1995.7093704677552, 0.046747028748134176, 0.053077923710081035
# Delta: wavelength: 409.186, peak intensity: 334.03828
# middle width: 6.073617183556678, top width: 1.7313097425623596, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 1719.77321
# middle width: 6.3994841382797745, top width: 1.251464648877743, saturated: False
# Beta: wavelength: 484.973, peak intensity: 32387.70754
# middle width: 7.145549734918745, top width: 0.8846613844237936, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 3097.91548
# middle width: 2.8985776781294135, top width: 0.7185411692064463, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 45809.81277
# middle width: 9.1414324037612, top width: 1.5734916545500255, saturated: False
# Delta gaussian parameters: H = 156.94098772999803, A = 188.67261214215833, x0 = 408.9071976469373, sigma = 0.4208415978750773
# errors: 7.148470300346116, 26.05807528292856, 0.0658430891946114, 0.06958410478331217
# Gamma gaussian parameters: H = 169.48517274962776, A = 1315.5560251499369, x0 = 432.5132429977568, sigma = 0.7114178370647265
# errors: 34.847594892904695, 86.55124930057934, 0.051799733106620206, 0.05824940370771107
# Beta gaussian parameters: H = 416.9580764428113, A = 27373.78078314985, x0 = 484.5347562090855, sigma = 0.7410184507868256
# errors: 696.0646478101162, 1651.7415455958676, 0.04929789113625468, 0.05602952088872254
# Fulcher gaussian parameters: H = 317.5164241798168, A = 2439.7732991952903, x0 = 588.3815927121981, sigma = 0.37002911958588414
# errors: 42.23118356387732, 161.9205306332419, 0.02786009705904286, 0.02930901331200352
# Alpha gaussian parameters: H = 2195.9085561177394, A = 34565.68953076726, x0 = 655.4589167798559, sigma = 1.1208635913583735
# errors: 1897.4924000917383, 2730.5342950377444, 0.08875418426653627, 0.12366593733179691
# Delta: wavelength: 409.186, peak intensity: 396.92769
# middle width: 11.427147940759426, top width: 1.8772357162704907, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 2022.3640699999999
# middle width: 7.75963792155585, top width: 1.0065312679353724, saturated: False
# Beta: wavelength: 484.973, peak intensity: 38540.91493
# middle width: 7.879298757360857, top width: 0.8807493502220041, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 3345.21325
# middle width: 2.8224504600548244, top width: 0.6148592090157763, saturated: False
# Alpha: wavelength: 655.449, peak intensity: 52320.31234
# middle width: 5.057417393786864, top width: 1.3831973655801448, saturated: False
# Delta gaussian parameters: H = 190.29789065183587, A = 215.22617789652924, x0 = 408.89888270123544, sigma = 0.4674341258705191
# errors: 9.489063416946262, 32.26821418078872, 0.07915482182587943, 0.08433066232845207
# Gamma gaussian parameters: H = 198.18270361311846, A = 1550.7788884218992, x0 = 432.44867070369094, sigma = 0.763932381974158
# errors: 41.5019960455889, 97.06295152820411, 0.05261829048361022, 0.06003940342007183
# Beta gaussian parameters: H = 376.5292477891875, A = 33269.01103344483, x0 = 484.4908973252789, sigma = 0.773897318921289
# errors: 835.6294153333547, 1909.5804052451717, 0.048787797755890296, 0.05598917090650601
# Fulcher gaussian parameters: H = 343.32885853796927, A = 2612.2863237179245, x0 = 588.3757094586061, sigma = 0.36222686448066077
# errors: 46.10722054971863, 179.18378828153504, 0.0282016052889756, 0.029627796680885193
# Alpha gaussian parameters: H = 550.5862387129976, A = 49955.65106729531, x0 = 655.2567427818801, sigma = 0.4625883170206139
# errors: 450.2474381594388, 1466.6564442033607, 0.015299636007299956, 0.016401802969021783
# Delta: wavelength: 408.971, peak intensity: 535.89986
# middle width: 6.5794945637235855, top width: 1.5817639427832546, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 2946.2309800000003
# middle width: 7.8079705539572615, top width: 0.6789922068739997, saturated: False
# Beta: wavelength: 484.973, peak intensity: 50952.619000000006
# middle width: 8.137223298685285, top width: 0.7257969368620252, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 4542.54852
# middle width: 2.9452302628585585, top width: 0.6575850774620449, saturated: False
# Alpha: wavelength: 655.249, peak intensity: 63266.09014
# middle width: 5.471199178379948, top width: 1.5455749090604058, saturated: False
# Delta gaussian parameters: H = 255.21079200597543, A = 284.9719446611735, x0 = 408.90423993011973, sigma = 0.43724708022528785
# errors: 11.93208740613756, 42.41978230097516, 0.07365774411892179, 0.07805976218929779
# Gamma gaussian parameters: H = 251.92095079629956, A = 2165.234170232854, x0 = 432.4338921136118, sigma = 0.7975450053457763
# errors: 63.44662499380264, 142.8799385504428, 0.057681461962046675, 0.06647996726638583
# Beta gaussian parameters: H = 341.23573352572186, A = 43305.543524728804, x0 = 484.4755958198892, sigma = 0.8044520110508626
# errors: 1112.8186775740605, 2456.3279261747225, 0.049923807093272, 0.057843652986554646
# Fulcher gaussian parameters: H = 463.4532794696512, A = 3577.335785848564, x0 = 588.3902410429329, sigma = 0.3791038188129874
# errors: 60.51572952623331, 228.46929136384765, 0.027451675682247028, 0.028925898693135114
# Alpha gaussian parameters: H = 596.233381488354, A = 61669.90250912558, x0 = 655.2404623642522, sigma = 0.4877754471931947
# errors: 499.3079398147582, 1567.500589779194, 0.01394122338129763, 0.015022942814410224
# Delta: wavelength: 409.186, peak intensity: 938.38496
# middle width: 5.653957078305382, top width: 1.0399644710795997, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 4938.20741
# middle width: 6.374155051666946, top width: 1.0032590516951814, saturated: False
# Beta: wavelength: 484.76199999999994, peak intensity: 63199.81007000001
# middle width: 9.394684918252892, top width: 3.2376166967274003, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 7511.25116
# middle width: 4.845504111017817, top width: 0.9351421872020182, saturated: False
# Alpha: wavelength: 655.049, peak intensity: 63199.81007000001
# middle width: 7.463391107481357, top width: 3.6734292928961167, saturated: False
# Delta gaussian parameters: H = 398.0314529990513, A = 543.2779365385185, x0 = 408.9044080694662, sigma = 0.4488227463843592
# errors: 18.010235904276236, 62.9313379213292, 0.05879301564590358, 0.06243162168090201
# Gamma gaussian parameters: H = 457.17739847623204, A = 3716.510880840399, x0 = 432.4930984170852, sigma = 0.7363899269425488
# errors: 105.21933180854784, 253.92128461346442, 0.05553673083671361, 0.06287610771773557
# Beta gaussian parameters: H = 529.8220195176604, A = 60420.28812496471, x0 = 484.45435490218154, sigma = 0.8233419573995195
# errors: 1541.7743576020616, 3331.1763093348504, 0.049544903901071316, 0.057762633916756505
# Fulcher gaussian parameters: H = 741.8761232883503, A = 6019.388969161303, x0 = 588.3999610206932, sigma = 0.384879666620215
# errors: 102.46663421358902, 383.11980973450056, 0.027763992218956157, 0.029285952707400698
# Alpha gaussian parameters: H = 178.7530451263648, A = 67937.90661428607, x0 = 655.1936514612754, sigma = 0.596457291763708
# errors: 591.7069962508151, 1601.8016493192772, 0.01567020807386064, 0.017310162963278686
# Delta: wavelength: 409.186, peak intensity: 1121.62249
# middle width: 6.3176940342193575, top width: 2.1102834184998187, saturated: False
# Gamma: wavelength: 432.97, peak intensity: 5801.93016
# middle width: 7.512029745880852, top width: 1.1715411572778862, saturated: False
# Beta: wavelength: 484.973, peak intensity: 62932.741420000006
# middle width: 10.076769953158646, top width: 3.7100832029525463, saturated: False
# Fulcher: wavelength: 588.186, peak intensity: 11676.53064
# middle width: 4.998526853513567, top width: 0.9585208351484198, saturated: False
# Alpha: wavelength: 655.049, peak intensity: 63185.51391
# middle width: 41.46955291451695, top width: 4.517533617202844, saturated: False
# Delta gaussian parameters: H = 463.2640858022542, A = 671.4644328722725, x0 = 408.8644133981089, sigma = 0.47575527269527423
# errors: 21.970892889978696, 73.82933620257853, 0.059049842364985, 0.06300443254015126
# Gamma gaussian parameters: H = 480.0115212247293, A = 4466.562443944674, x0 = 432.4415496365392, sigma = 0.7709267509700762
# errors: 126.67080379919385, 293.93478965326085, 0.055780561401528414, 0.06377678659714703
# Beta gaussian parameters: H = 186.09880836792223, A = 63793.287596203336, x0 = 484.3765462733035, sigma = 0.8601840991154464
# errors: 1437.5706538983786, 2980.6217308664986, 0.04363404444952999, 0.05151848756697334
# Fulcher gaussian parameters: H = 1094.1860557404518, A = 9407.742465794972, x0 = 588.4013858508881, sigma = 0.391693935174095
# errors: 158.18768187823903, 584.7762513782095, 0.027585722814044963, 0.029132320909285463
# Alpha gaussian parameters: H = -8607.718049898327, A = 62777.81680517752, x0 = 655.9048686052574, sigma = 2.080858410737618
# errors: 9022.35552982844, 8448.977008685433, 0.12751990017522835, 0.3339869336657733
